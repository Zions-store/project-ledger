# %% [markdown]
# # Analysis notebook (seed)
#
# This is a small, human-readable SEED that documents the intended
# structure of the 4.1b fixture. The large (>512 KiB) notebook that the
# test actually consumes is generated deterministically into the work
# copy by `setup_fixture.py`; it is never committed. See `SETUP.md`.

# %%
import numpy as np
import pandas as pd

# %%
def load(path):
    return pd.read_csv(path)
